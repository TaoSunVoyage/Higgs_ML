# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
from proj1_helpers import *
from implementations import *

# %%
def standardize(x, mean_x=None, std_x=None):
    """Standardize the original data set."""
    if mean_x is None:
        mean_x = np.nanmean(x, axis=0)
    if std_x is None:
        std_x = np.nanstd(x, axis=0)
    x = x - mean_x
    x = x / std_x
    return x, mean_x, std_x

def build_poly(x, degree):
    """polynomial basis functions for input data x, for j=0 up to j=degree."""
    poly = np.ones((len(x), 1))
    for deg in range(1, degree+1):
        poly = np.c_[poly, np.power(x, deg)]
    return poly

def split_data(x, y, ratio, myseed=1):
    """split the dataset based on the split ratio."""
    # set seed
    np.random.seed(myseed)
    # generate random indices
    num_row = len(y)
    indices = np.random.permutation(num_row)
    index_split = int(np.floor(ratio * num_row))
    index_tr = indices[: index_split]
    index_te = indices[index_split:]
    # create split
    x_tr = x[index_tr]
    x_te = x[index_te]
    y_tr = y[index_tr]
    y_te = y[index_te]
    return x_tr, x_te, y_tr, y_te

# %%
def accuracy(y_pred, y_true):
    return (y_pred == y_true).sum()/len(y_true)

# %%
def tozeroone(y):
    """[-1, 1] -> [0, 1]"""
    return (y + 1) / 2
def tonegposone(y):
    """[0, 1] -> [-1, 1]"""
    return y * 2 - 1

# %%
# data path
train_data_path = "../data/train.csv"
test_data_path = "../data/test.csv"

# load training and test set
y_train_data, x_train_data, id_train_data = load_csv_data(train_data_path)
y_test_data, x_test_data, id_test_data = load_csv_data(test_data_path)

# number of samples
N = x_tr.shape[0]
# number of features
m = x_tr.shape[1]

# %%
N, m
# Out:
# (200000, 30)

# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd

# %%
df_train = pd.read_csv(train_data_path, index_col='Id')
df_train = df_train[df_train.columns[1:]]

# %%
feature_name = df_train.columns
feature_name
# Out:
# Index(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt'],
#       dtype='object')

# %%
df_train = df_train.replace(-999, np.nan)

# %%
df_train[df_train["PRI_jet_num"]==0].describe().T
# Out:
#                                count        mean        std     min     25%  \
# DER_mass_MMC                 73790.0  120.667654  51.750062   9.044  90.241
# DER_mass_transverse_met_lep  99913.0   58.786239  32.003551   0.002  35.062
# DER_mass_vis                 99913.0   81.870309  38.043669   7.120  60.947
# DER_pt_h                     99913.0   13.823867  16.674707   0.000   2.275
# DER_deltaeta_jet_jet             0.0         NaN        NaN     NaN     NaN
# DER_mass_jet_jet                 0.0         NaN        NaN     NaN     NaN
# DER_prodeta_jet_jet              0.0         NaN        NaN     NaN     NaN
# DER_deltar_tau_lep           99913.0    2.664961   0.693295   0.277   2.338
# DER_pt_tot                   99913.0   13.823867  16.674707   0.000   2.275
# DER_sum_pt                   99913.0   76.377011  23.561057  46.104  61.297
# DER_pt_ratio_lep_tau         99913.0    1.392763   0.581596   0.127   0.968
# DER_met_phi_centrality       99913.0   -0.910077   0.936707  -1.414  -1.404
# DER_lep_eta_centrality           0.0         NaN        NaN     NaN     NaN
# PRI_tau_pt                   99913.0   34.012723  15.229541  20.000  23.655
# PRI_tau_eta                  99913.0   -0.024858   1.233430  -2.499  -0.960
# PRI_tau_phi                  99913.0   -0.015657   1.817351  -3.142  -1.586
# PRI_lep_pt                   99913.0   42.364287  14.585979  26.000  31.863
# PRI_lep_eta                  99913.0   -0.052311   1.310855  -2.505  -1.121
# PRI_lep_phi                  99913.0    0.042352   1.817844  -3.142  -1.526
# PRI_met                      99913.0   31.536761  20.294541   0.109  18.001
# PRI_met_phi                  99913.0   -0.024443   1.811006  -3.142  -1.583
# PRI_met_sumet                99913.0  125.860810  53.086600  13.678  87.951
# PRI_jet_num                  99913.0    0.000000   0.000000   0.000   0.000
# PRI_jet_leading_pt               0.0         NaN        NaN     NaN     NaN
# PRI_jet_leading_eta              0.0         NaN        NaN     NaN     NaN
# PRI_jet_leading_phi              0.0         NaN        NaN     NaN     NaN
# PRI_jet_subleading_pt            0.0         NaN        NaN     NaN     NaN
# PRI_jet_subleading_eta           0.0         NaN        NaN     NaN     NaN
# PRI_jet_subleading_phi           0.0         NaN        NaN     NaN     NaN
# PRI_jet_all_pt               99913.0    0.000000   0.000000   0.000   0.000
#
#                                  50%       75%       max
# DER_mass_MMC                 111.452  137.3885   863.647
# DER_mass_transverse_met_lep   62.144   79.6500   570.115
# DER_mass_vis                  75.533   94.1350  1349.351
# DER_pt_h                       6.677   24.2020  2834.999
# DER_deltaeta_jet_jet             NaN       NaN       NaN
# DER_mass_jet_jet                 NaN       NaN       NaN
# DER_prodeta_jet_jet              NaN       NaN       NaN
# DER_deltar_tau_lep             2.822    3.0950     5.684
# DER_pt_tot                     6.677   24.2020  2834.999
# DER_sum_pt                    71.586   85.2420  1324.678
# DER_pt_ratio_lep_tau           1.318    1.7280    10.571
# DER_met_phi_centrality        -1.364   -1.1230     1.414
# DER_lep_eta_centrality           NaN       NaN       NaN
# PRI_tau_pt                    29.329   39.8080   764.408
# PRI_tau_eta                   -0.043    0.9000     2.494
# PRI_tau_phi                   -0.049    1.5560     3.142
# PRI_lep_pt                    38.969   49.0070   560.271
# PRI_lep_eta                   -0.104    0.9890     2.503
# PRI_lep_phi                    0.085    1.6210     3.142
# PRI_met                       29.538   42.2730  2842.617
# PRI_met_phi                   -0.051    1.5460     3.142
# PRI_met_sumet                119.479  156.4180  1391.529
# PRI_jet_num                    0.000    0.0000     0.000
# PRI_jet_leading_pt               NaN       NaN       NaN
# PRI_jet_leading_eta              NaN       NaN       NaN
# PRI_jet_leading_phi              NaN       NaN       NaN
# PRI_jet_subleading_pt            NaN       NaN       NaN
# PRI_jet_subleading_eta           NaN       NaN       NaN
# PRI_jet_subleading_phi           NaN       NaN       NaN
# PRI_jet_all_pt                 0.000    0.0000     0.000

# %%
df_train[df_train["PRI_jet_num"]==1].describe().T
# Out:
#                                count        mean        std     min  \
# DER_mass_MMC                 69982.0  122.182109  59.344924   9.806
# DER_mass_transverse_met_lep  77544.0   46.053600  35.581190   0.000
# DER_mass_vis                 77544.0   82.219033  42.288122   6.329
# DER_pt_h                     77544.0   65.903090  47.431007   0.000
# DER_deltaeta_jet_jet             0.0         NaN        NaN     NaN
# DER_mass_jet_jet                 0.0         NaN        NaN     NaN
# DER_prodeta_jet_jet              0.0         NaN        NaN     NaN
# DER_deltar_tau_lep           77544.0    2.339686   0.737633   0.208
# DER_pt_tot                   77544.0   16.645000  17.007924   0.000
# DER_sum_pt                   77544.0  150.368035  65.182087  77.017
# DER_pt_ratio_lep_tau         77544.0    1.444185   0.846425   0.083
# DER_met_phi_centrality       77544.0    0.235612   1.106340  -1.414
# DER_lep_eta_centrality           0.0         NaN        NaN     NaN
# PRI_tau_pt                   77544.0   38.589368  21.005700  20.000
# PRI_tau_eta                  77544.0   -0.001735   1.218195  -2.498
# PRI_tau_phi                  77544.0   -0.007312   1.814460  -3.141
# PRI_lep_pt                   77544.0   46.766503  21.335552  26.000
# PRI_lep_eta                  77544.0    0.006686   1.262214  -2.494
# PRI_lep_phi                  77544.0    0.044894   1.815456  -3.142
# PRI_met                      77544.0   40.123371  28.357324   0.251
# PRI_met_phi                  77544.0   -0.005579   1.811937  -3.141
# PRI_met_sumet                77544.0  203.324833  81.901141  21.066
# PRI_jet_num                  77544.0    1.000000   0.000000   1.000
# PRI_jet_leading_pt           77544.0   65.012163  45.154510  30.000
# PRI_jet_leading_eta          77544.0   -0.000800   1.821593  -4.499
# PRI_jet_leading_phi          77544.0   -0.015052   1.817529  -3.142
# PRI_jet_subleading_pt            0.0         NaN        NaN     NaN
# PRI_jet_subleading_eta           0.0         NaN        NaN     NaN
# PRI_jet_subleading_phi           0.0         NaN        NaN     NaN
# PRI_jet_all_pt               77544.0   65.012163  45.154510  30.000
#
#                                    25%       50%        75%       max
# DER_mass_MMC                  92.15325  112.4055  136.13175  1192.026
# DER_mass_transverse_met_lep   16.26750   40.4985   70.01300   571.868
# DER_mass_vis                  59.80975   73.9360   92.67975   959.601
# DER_pt_h                      37.13100   53.0810   79.00200   753.745
# DER_deltaeta_jet_jet               NaN       NaN        NaN       NaN
# DER_mass_jet_jet                   NaN       NaN        NaN       NaN
# DER_prodeta_jet_jet                NaN       NaN        NaN       NaN
# DER_deltar_tau_lep             1.85500    2.4040    2.85500     5.655
# DER_pt_tot                     2.89500   10.7050   26.21425   330.527
# DER_sum_pt                   110.75275  132.3265  167.62400  1214.932
# DER_pt_ratio_lep_tau           0.86775    1.2680    1.79700    16.776
# DER_met_phi_centrality        -0.97500    0.6265    1.32400     1.414
# DER_lep_eta_centrality             NaN       NaN        NaN       NaN
# PRI_tau_pt                    24.83100   32.1595   45.26600   505.060
# PRI_tau_eta                   -0.92200   -0.0110    0.91100     2.497
# PRI_tau_phi                   -1.56500   -0.0330    1.56600     3.141
# PRI_lep_pt                    32.38600   40.5645   54.12725   426.398
# PRI_lep_eta                   -0.97500    0.0160    0.98425     2.502
# PRI_lep_phi                   -1.52200    0.0940    1.61825     3.142
# PRI_met                       21.80075   34.5685   51.06900   536.468
# PRI_met_phi                   -1.57900   -0.0110    1.56800     3.142
# PRI_met_sumet                148.36200  189.4760  240.65775  1383.552
# PRI_jet_num                    1.00000    1.0000    1.00000     1.000
# PRI_jet_leading_pt            37.52900   49.9740   74.59225   743.222
# PRI_jet_leading_eta           -1.34600   -0.0020    1.34700     4.492
# PRI_jet_leading_phi           -1.59400   -0.0390    1.56400     3.141
# PRI_jet_subleading_pt              NaN       NaN        NaN       NaN
# PRI_jet_subleading_eta             NaN       NaN        NaN       NaN
# PRI_jet_subleading_phi             NaN       NaN        NaN       NaN
# PRI_jet_all_pt                37.52900   49.9740   74.59225   743.222

# %%
df_train[df_train["PRI_jet_num"]==2].describe().T
# Out:
#                                count        mean         std      min  \
# DER_mass_MMC                 47427.0  122.653136   55.749630    9.878
# DER_mass_transverse_met_lep  50379.0   38.343612   35.273944    0.000
# DER_mass_vis                 50379.0   79.213348   39.917128    7.330
# DER_pt_h                     50379.0  102.985028   70.529284    0.120
# DER_deltaeta_jet_jet         50379.0    2.606534    1.812621    0.000
# DER_mass_jet_jet             50379.0  391.406450  426.852418   13.602
# DER_prodeta_jet_jet          50379.0   -1.115458    3.821072  -18.066
# DER_deltar_tau_lep           50379.0    2.060607    0.759354    0.228
# DER_pt_tot                   50379.0   17.280603   20.409682    0.004
# DER_sum_pt                   50379.0  245.776275  101.356966  110.601
# DER_pt_ratio_lep_tau         50379.0    1.453461    1.034396    0.047
# DER_met_phi_centrality       50379.0    0.565613    0.978247   -1.414
# DER_lep_eta_centrality       50379.0    0.492868    0.398569    0.000
# PRI_tau_pt                   50379.0   44.652267   27.984075   20.000
# PRI_tau_eta                  50379.0   -0.000776    1.172190   -2.495
# PRI_tau_phi                  50379.0    0.006934    1.815839   -3.141
# PRI_lep_pt                   50379.0   50.943938   26.882020   26.001
# PRI_lep_eta                  50379.0   -0.003467    1.193624   -2.487
# PRI_lep_phi                  50379.0    0.046821    1.815332   -3.142
# PRI_met                      50379.0   53.757369   40.230662    0.200
# PRI_met_phi                  50379.0    0.003340    1.814845   -3.142
# PRI_met_sumet                50379.0  296.011170  111.483795   34.323
# PRI_jet_num                  50379.0    2.000000    0.000000    2.000
# PRI_jet_leading_pt           50379.0   98.470208   61.866979   30.196
# PRI_jet_leading_eta          50379.0   -0.002448    1.814152   -4.497
# PRI_jet_leading_phi          50379.0   -0.013290    1.809918   -3.142
# PRI_jet_subleading_pt        50379.0   51.709866   25.460068   30.000
# PRI_jet_subleading_eta       50379.0   -0.013631    2.134823   -4.500
# PRI_jet_subleading_phi       50379.0    0.006144    1.817867   -3.142
# PRI_jet_all_pt               50379.0  150.180076   77.646249   60.223
#
#                                   25%      50%       75%       max
# DER_mass_MMC                  95.6960  115.254  133.7420   966.986
# DER_mass_transverse_met_lep   11.6055   28.501   56.5120   595.819
# DER_mass_vis                  58.5250   72.270   89.5055  1051.358
# DER_pt_h                      54.0655   87.682  134.1345  1053.807
# DER_deltaeta_jet_jet           0.9840    2.383    4.0040     8.503
# DER_mass_jet_jet             106.6760  228.643  513.6745  4974.979
# DER_prodeta_jet_jet           -3.2510   -0.465    0.8690    16.690
# DER_deltar_tau_lep             1.4850    2.020    2.6320     5.579
# DER_pt_tot                     2.7745    9.569   25.9670   513.659
# DER_sum_pt                   177.7020  218.683  283.0885  1282.523
# DER_pt_ratio_lep_tau           0.7670    1.202    1.8200    19.773
# DER_met_phi_centrality        -0.0170    1.051    1.3400     1.414
# DER_lep_eta_centrality         0.0140    0.551    0.9040     1.000
# PRI_tau_pt                    26.4015   36.212   53.0525   622.862
# PRI_tau_eta                   -0.8750   -0.008    0.8680     2.491
# PRI_tau_phi                   -1.5570    0.001    1.5780     3.142
# PRI_lep_pt                    32.9355   42.648   59.6705   447.878
# PRI_lep_eta                   -0.9020   -0.009    0.8980     2.499
# PRI_lep_phi                   -1.5160    0.085    1.6170     3.141
# PRI_met                       26.8615   44.167   69.0425   951.363
# PRI_met_phi                   -1.5605   -0.003    1.5760     3.142
# PRI_met_sumet                220.2190  274.747  346.4370  1364.632
# PRI_jet_num                    2.0000    2.000    2.0000     2.000
# PRI_jet_leading_pt            56.6175   80.543  120.3560  1120.573
# PRI_jet_leading_eta           -1.4160    0.015    1.4030     4.499
# PRI_jet_leading_phi           -1.5780   -0.032    1.5530     3.141
# PRI_jet_subleading_pt         35.2455   43.551   58.7125   464.262
# PRI_jet_subleading_eta        -1.7570   -0.013    1.7250     4.500
# PRI_jet_subleading_phi        -1.5685    0.012    1.5890     3.142
# PRI_jet_all_pt                96.9115  128.486  179.9955  1173.613

# %%
df_train[df_train["PRI_jet_num"]==3].describe().T
# Out:
#                                count        mean         std      min  \
# DER_mass_MMC                 20687.0  123.189990   70.899464   15.731
# DER_mass_transverse_met_lep  22164.0   42.120203   38.075038    0.000
# DER_mass_vis                 22164.0   78.925522   48.790879   10.342
# DER_pt_h                     22164.0  126.066343   83.821859    0.777
# DER_deltaeta_jet_jet         22164.0    1.942770    1.469926    0.000
# DER_mass_jet_jet             22164.0  327.179877  317.279844   17.084
# DER_prodeta_jet_jet          22164.0   -0.153947    2.867334  -15.347
# DER_deltar_tau_lep           22164.0    1.884620    0.827260    0.379
# DER_pt_tot                   22164.0   53.548536   32.299212    0.040
# DER_sum_pt                   22164.0  358.008310  150.138383  145.486
# DER_pt_ratio_lep_tau         22164.0    1.580736    1.247161    0.081
# DER_met_phi_centrality       22164.0    0.545345    0.943359   -1.414
# DER_lep_eta_centrality       22164.0    0.379694    0.387636    0.000
# PRI_tau_pt                   22164.0   46.770938   32.430840   20.001
# PRI_tau_eta                  22164.0   -0.003881    1.204737   -2.496
# PRI_tau_phi                  22164.0   -0.011762    1.824155   -3.141
# PRI_lep_pt                   22164.0   55.916913   32.966571   26.001
# PRI_lep_eta                  22164.0    0.000269    1.217684   -2.485
# PRI_lep_phi                  22164.0    0.036735    1.818101   -3.142
# PRI_met                      22164.0   65.818764   49.698410    0.208
# PRI_met_phi                  22164.0    0.007977    1.812382   -3.141
# PRI_met_sumet                22164.0  414.852725  158.829033   22.710
# PRI_jet_num                  22164.0    3.000000    0.000000    3.000
# PRI_jet_leading_pt           22164.0  123.107808   76.313756   31.266
# PRI_jet_leading_eta          22164.0   -0.013810    1.573264   -4.439
# PRI_jet_leading_phi          22164.0   -0.001050    1.806774   -3.141
# PRI_jet_subleading_pt        22164.0   71.248456   40.126329   30.235
# PRI_jet_subleading_eta       22164.0   -0.007787    1.775354   -4.491
# PRI_jet_subleading_phi       22164.0   -0.019144    1.814782   -3.142
# PRI_jet_all_pt               22164.0  255.320458  128.454234   92.812
#
#                                    25%       50%        75%       max
# DER_mass_MMC                  88.88800  107.5340  132.36200   988.199
# DER_mass_transverse_met_lep   13.42575   32.1650   62.18800   690.075
# DER_mass_vis                  54.03725   67.9910   87.76325  1329.913
# DER_pt_h                      65.49775  108.9090  166.42025   762.806
# DER_deltaeta_jet_jet           0.71400    1.6345    2.87700     7.877
# DER_mass_jet_jet             123.78975  221.3345  411.92700  4062.147
# DER_prodeta_jet_jet           -1.34525   -0.0150    1.11925    14.772
# DER_deltar_tau_lep             1.23000    1.7670    2.49100     5.505
# DER_pt_tot                    33.20825   45.6945   66.12125   466.525
# DER_sum_pt                   254.99650  320.5840  417.14875  1852.462
# DER_pt_ratio_lep_tau           0.78200    1.2610    1.98400    19.672
# DER_met_phi_centrality         0.01500    0.9660    1.32000     1.414
# DER_lep_eta_centrality         0.00000    0.2350    0.78525     1.000
# PRI_tau_pt                    26.29000   36.1105   55.25300   449.648
# PRI_tau_eta                   -0.91900   -0.0050    0.91100     2.497
# PRI_tau_phi                   -1.59200   -0.0285    1.57500     3.141
# PRI_lep_pt                    34.21800   45.6825   65.94450   461.896
# PRI_lep_eta                   -0.92925    0.0110    0.93300     2.497
# PRI_lep_phi                   -1.52325    0.0650    1.60500     3.140
# PRI_met                       32.05425   53.2495   85.10075   695.533
# PRI_met_phi                   -1.54800    0.0090    1.56225     3.141
# PRI_met_sumet                306.53625  382.9215  486.14450  2003.976
# PRI_jet_num                    3.00000    3.0000    3.00000     3.000
# PRI_jet_leading_pt            71.51525  101.6815  150.18725   760.846
# PRI_jet_leading_eta           -1.17925   -0.0225    1.16325     4.476
# PRI_jet_leading_phi           -1.55900   -0.0180    1.57800     3.141
# PRI_jet_subleading_pt         46.00675   59.7995   82.94075   721.456
# PRI_jet_subleading_eta        -1.32600    0.0000    1.32600     4.500
# PRI_jet_subleading_phi        -1.59325   -0.0410    1.54800     3.141
# PRI_jet_all_pt               167.90050  222.1575  304.90400  1633.433

# %% [markdown]
# ## Preprocessing

# %%
def preprocessing(input_data):
    data = input_data.copy()
    # replace -999 with nan
    data[data == -999] = np.nan

    # replace nan with the most frequent elemet
    for i in range(data.shape[1]):
        data_i = data[:, i]
        u, counts = np.unique(data_i, return_counts=True)
        most_freq = u[np.argmax(counts)]
        data_i[data_i!=data_i] = most_freq

    # get mean and std
    mean = np.mean(data, axis=0)
    std = np.std(data, axis=0)

    # normalize
    data = data - mean
    data = data / std
    
    return data

# %%
data = preprocessing(x_train_data)

# %%
data
# Out:
# array([[ 0.3827365 ,  0.06833197,  0.40768027, ...,  1.83381567,
#         -0.69661581,  0.4125105 ],
#        [ 0.80239171,  0.55250482,  0.54013641, ..., -0.36652212,
#         -0.4496554 , -0.27381996],
#        [-0.40279783,  3.19515553,  1.09655998, ..., -0.36652212,
#         -0.4496554 , -0.29396985],
#        ...,
#        [-0.23390468,  0.31931645, -0.13086367, ..., -0.36652212,
#         -0.4496554 , -0.31701723],
#        [-0.4301435 , -0.84532397, -0.30297338, ..., -0.36652212,
#         -0.4496554 , -0.74543941],
#        [-0.40279783,  0.66533608, -0.25352276, ..., -0.36652212,
#         -0.4496554 , -0.74543941]])

# %%
data.mean(0)
# Out:
# array([  1.82705611e-12,   4.49575133e-15,  -3.48448848e-15,
#          7.18646387e-15,  -4.54941415e-13,  -1.32736188e-12,
#         -3.61011410e-15,   2.16223188e-14,   6.40057962e-15,
#          2.86143687e-15,  -6.98486646e-15,   3.63458152e-15,
#         -1.02319619e-15,  -5.95722149e-15,   1.35646161e-16,
#          7.13136217e-17,   2.58023760e-14,  -1.06327391e-16,
#         -1.87188487e-16,   8.24115935e-15,   1.41040513e-16,
#         -8.99509711e-15,  -6.01698247e-16,   7.06883188e-13,
#          9.08278244e-14,  -1.05442427e-13,   8.84288113e-13,
#         -7.17539436e-13,   2.75050842e-12,  -1.77122317e-15])

# %%
data[:, 0][:4]
# Out:
# array([ 0.13631768,  0.32068721,  3.        ,  0.18091858])

# %%
u[np.argmax(counts)-4:np.argmax(counts)+4]
# Out:
# array([ 96.411,  96.412,  96.413,  96.414,  96.415,  96.416,  96.417,
#         96.418])

# %% [markdown]
# ## Create train and validataion set

# %%
x_tr, x_va, y_tr, y_va = split_data(x_tr, y_tr, 0.8)

# %%
x_tr.shape[0], x_va.shape[0]
# Out:
# (200000, 50000)

# %% [markdown]
# ## Preprocessing + Feature Engineering

# %%
# TODO: more sophisticated data preprocessing
# replace missing data with nan
x_tr[x_tr == -999] = np.nan
x_va[x_va == -999] = np.nan
x_te[x_te == -999] = np.nan
# normalize
x_tr, mean, std = standardize(x_tr)
x_va, _, _ = standardize(x_va, mean, std)
x_te, _, _ = standardize(x_te, mean, std)
# fill nan
x_tr = np.nan_to_num(x_tr)
x_va = np.nan_to_num(x_va)
x_te = np.nan_to_num(x_te)

# %% [markdown]
# ## Ridge Regression

# %%
lambda_ = 0.001

w, loss = ridge_regression(y_tr, x_tr, lambda_)

y_pred = predict_labels(w, x_va)

accuracy(y_pred, y_va)
# Out:
# 0.71636

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### L2 Normalization and SGD

# %%
# initialize weights
initial_w = np.random.rand(m)

# TODO: cross validataion
# hyperparameters
max_iters = 100
gamma = 0.00001
lambda_ = 0.1

# %%
# run regression
y_tr_log = tozeroone(y_tr)
# initialize weight
w = initial_w

losses = []
for n_iter in range(max_iters):
    # compute a gradient
    grad = compute_gradient_reg_logistic(y_tr_log, x_tr, w, lambda_)
    # update w through the gradient update
    w = w - gamma * grad
    # calculate loss
    loss = compute_nl_loss_regularization(y_tr_log, x_tr, w, lambda_)
    losses.append(loss)

plt.plot(losses)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-7a67f733f45c> in <module>()
#      14     losses.append(loss)
#      15
# ---> 16 plt.plot(losses/N)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
y_pred = predict_labels(w, x_va)

accuracy(y_pred, y_va)
# Out:
# 0.68522000000000005

# %% [markdown]
# ### L2 Normalization and GD

# %% [markdown]
# ### L1 Normaliziation and SGD

# %% [markdown]
# ## Create submission

# %%
# predict
y_pred = predict_labels(weights, x_te)

# create submission
name = "submission.csv"
create_csv_submission(id_te, y_pred, name)
